# %%
# Dependencies and Setup
import pandas as pd
import os

# File to Load (Remember to Change These)
school_data_to_load = os.path.join('..','Resources','schools_complete.csv')
student_data_to_load = os.path.join('..','Resources','students_complete.csv')

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head(10)
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
# 5           5      Bryan Miranda      M   9th  Huang High School
# 6           6      Sheena Carter      F  11th  Huang High School
# 7           7       Nicole Baker      F  12th  Huang High School
# 8           8       Michael Roth      M  10th  Huang High School
# 9           9     Matthew Greene      M  10th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# ...

# %%
school_count = school_data_complete['school_name'].nunique()
school_count
# Out:
# 15

# %%
student_count = school_data_complete['Student ID'].nunique()
student_count
# Out:
# 39170

# %%
total_budget = school_data_complete['budget'].sum()

total_budget
# Out:
# 82932329558

# %%
avg_math = school_data_complete['math_score'].mean()

avg_math
# Out:
# 78.98537145774827

# %%
avg_read = school_data_complete['reading_score'].mean()

avg_read
# Out:
# 81.87784018381414

# %%
math_pass_ct = school_data_complete[(school_data_complete['math_score'] >= 70)].count()["student_name"]
math_pass_perc = math_pass_ct / student_count * 100

math_pass_perc
# Out:
# 74.9808526933878

# %%
read_pass_ct = school_data_complete[(school_data_complete['reading_score'] >= 70)].count()["student_name"]
read_pass_perc = read_pass_ct / float(student_count) * 100

read_pass_perc
# Out:
# 85.80546336482001

# %%
overall_pass_ct = school_data_complete[
    (school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70)
].count()["student_name"]
overall_pass_perc = overall_pass_ct / student_count * 100

overall_pass_perc
# Out:
# 65.17232575950983

# %%
student_count = '{:,}'.format(student_count)
total_budget = "${:,}".format(total_budget)
avg_math = "{:.2f}".format(avg_math)
avg_read = "{:.2f}".format(avg_read)
math_pass_perc = "{:.2f}%".format(math_pass_perc)
read_pass_perc = "{:.2f}%".format(read_pass_perc)
overall_pass_perc = '{:.2f}%'.format(overall_pass_perc)
district_summary = pd.DataFrame({
    "Total Schools": [school_count],
    "Total Students": [student_count],
    "Total Budget": [total_budget],
    "Average Math": [avg_math],
    "Average Reading": [avg_read],
    "Math Passing Percent": [math_pass_perc],
    "Reading Passing Percent": [read_pass_perc],
    "Overall Passing Percent": [overall_pass_perc]
})
district_summary
# Out:
#    Total Schools Total Students     Total Budget Average Math Average Reading  \
# 0             15         39,170  $82,932,329,558        78.99           81.88
#
#   Math Passing Percent Reading Passing Percent Overall Passing Percent
# 0               74.98%                  85.81%                  65.17%

# %%
#-------------------------------------------------------------------------------------------------------------------

# %%
# Use the code provided to select the type per school from school_data
school_types = school_data.set_index(["school_name"])["type"]

# %%
school_type = school_data.groupby("school_name")["type"].sum()

# %%
per_school_counts = school_data.groupby("school_name")["size"].sum()

# %%
budget_by_school = school_data.groupby("school_name")["budget"].sum()
budget_by_school_percapita = budget_by_school / per_school_counts

# %%
avg_math_per_school = school_data_complete.groupby("school_name")["math_score"].mean()
avg_read_per_school = school_data_complete.groupby("school_name")["reading_score"].mean()

# %%
math_passing = (school_data_complete["math_score"] >= 70)
math_passing_perschool = school_data_complete[math_passing].groupby("school_name").size()
math_pass_perc_byschool = math_passing_perschool / per_school_counts *100

# %%
read_passing = (school_data_complete["reading_score"] >= 70)
read_passing_perschool = school_data_complete[read_passing].groupby("school_name").size()
read_pass_perc_byschool = read_passing_perschool / per_school_counts *100

# %%
students_passing_math_and_reading = school_data_complete[
    (school_data_complete["reading_score"] >= 70) & (school_data_complete["math_score"] >= 70)
]
school_students_passing_math_and_reading = students_passing_math_and_reading.groupby(["school_name"]).size()
overall_pass = school_students_passing_math_and_reading / per_school_counts *100

# %%
per_school_summary = pd.DataFrame({
    "School Type" : school_type,
    "Student Population" : per_school_counts,
    "Total School Budget" : budget_by_school,
    "Per Student Budget" : budget_by_school_percapita,
    "Average Math Score" : avg_math_per_school,
    "Average Reading Score" : avg_read_per_school,
    "Math Passing Rate" : math_pass_perc_byschool,
    "Reading Passing Rate" : read_pass_perc_byschool,
    "Overall Passing Rate" : overall_pass})

per_school_summary["Total School Budget"] = per_school_summary["Total School Budget"].map("${:,.2f}".format)
per_school_summary["Per Student Budget"] = per_school_summary["Per Student Budget"].map("${:,.2f}".format)

per_school_summary
# Out:
#                       School Type  Student Population Total School Budget  \
# school_name
# Bailey High School       District                4976       $3,124,928.00
# Cabrera High School       Charter                1858       $1,081,356.00
# Figueroa High School     District                2949       $1,884,411.00
# Ford High School         District                2739       $1,763,916.00
# Griffin High School       Charter                1468         $917,500.00
# Hernandez High School    District                4635       $3,022,020.00
# Holden High School        Charter                 427         $248,087.00
# Huang High School        District                2917       $1,910,635.00
# Johnson High School      District                4761       $3,094,650.00
# Pena High School          Charter                 962         $585,858.00
# Rodriguez High School    District                3999       $2,547,363.00
# ...

# %%
df1 = pd.DataFrame({
    
    "Overall passing%" : overall_pass})
topschools = df1.sort_values(by = "Overall passing%", ascending = False)
topschools.head(5)
# Out:
#                      Overall passing%
# school_name
# Cabrera High School         91.334769
# Thomas High School          90.948012
# Griffin High School         90.599455
# Wilson High School          90.582567
# Pena High School            90.540541

# %%
df2 = pd.DataFrame({
    "Overall passing%" : overall_pass})
topschools = df2.sort_values(by = "Overall passing%", ascending = True)
topschools.head(5)
# Out:
#                        Overall passing%
# school_name
# Rodriguez High School         52.988247
# Figueroa High School          53.204476
# Huang High School             53.513884
# Hernandez High School         53.527508
# Johnson High School           53.539172

# %%
#-------------------------------------------------------------------------------------------------------------------

# %%
# Use the code provided to separate the data by grade
ninth_graders = school_data_complete[school_data_complete["grade"] == "9th"]
tenth_graders = school_data_complete[school_data_complete["grade"] == "10th"]
eleventh_graders = school_data_complete[school_data_complete["grade"] == "11th"]
twelfth_graders = school_data_complete[school_data_complete["grade"] == "12th"]

# Group by `school_name` and take the mean of the `math_score` column for each grade level
ninth_grade_math_scores = ninth_graders.groupby("school_name")["math_score"].mean()
tenth_grade_math_scores = tenth_graders.groupby("school_name")["math_score"].mean()
eleventh_grade_math_scores = eleventh_graders.groupby("school_name")["math_score"].mean()
twelfth_grade_math_scores = twelfth_graders.groupby("school_name")["math_score"].mean()

# Combine each of the scores above into a single DataFrame called `math_scores_by_grade`
math_scores_by_grade = pd.DataFrame({
    "9th": ninth_grade_math_scores,
    "10th": tenth_grade_math_scores,
    "11th": eleventh_grade_math_scores,
    "12th": twelfth_grade_math_scores
})

# Minor data wrangling
math_scores_by_grade.index.name = None

# Display the DataFrame
math_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
# Group by `school_name` and take the mean of the `math_score` column for each grade level
ninth_grade_read_scores = ninth_graders.groupby("school_name")["reading_score"].mean()
tenth_grade_read_scores = tenth_graders.groupby("school_name")["reading_score"].mean()
eleventh_grade_read_scores = eleventh_graders.groupby("school_name")["reading_score"].mean()
twelfth_grade_read_scores = twelfth_graders.groupby("school_name")["reading_score"].mean()

# Combine each of the scores above into a single DataFrame called `math_scores_by_grade`
read_scores_by_grade = pd.DataFrame({
    "9th": ninth_grade_read_scores,
    "10th": tenth_grade_read_scores,
    "11th": eleventh_grade_read_scores,
    "12th": twelfth_grade_read_scores
})

# Minor data wrangling
read_scores_by_grade.index.name = None

# Display the DataFrame
read_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
# Establish the bins
spending_bins = [0, 585, 630, 645, 680]
labels = ["<$585", "$585-630", "$630-645", "$645-680"]

# %%
school_spending_df = per_school_summary.copy()
school_spending_df
# Out:
#                       School Type  Student Population Total School Budget  \
# school_name
# Bailey High School       District                4976       $3,124,928.00
# Cabrera High School       Charter                1858       $1,081,356.00
# Figueroa High School     District                2949       $1,884,411.00
# Ford High School         District                2739       $1,763,916.00
# Griffin High School       Charter                1468         $917,500.00
# Hernandez High School    District                4635       $3,022,020.00
# Holden High School        Charter                 427         $248,087.00
# Huang High School        District                2917       $1,910,635.00
# Johnson High School      District                4761       $3,094,650.00
# Pena High School          Charter                 962         $585,858.00
# Rodriguez High School    District                3999       $2,547,363.00
# ...

# %%
# Assuming the column contains strings with '$' and ',' characters
# Remove '$' and ',' characters and convert to numeric
school_spending_df['Per Student Budget'] = school_spending_df['Per Student Budget'].str.replace(',', '').str.replace('$', '').astype(float)

# Now, use pd.cut to categorize spending based on the bins
school_spending_df["Spending Ranges (Per Student)"] = pd.cut(school_spending_df["Per Student Budget"], bins=spending_bins, labels=labels)
school_spending_df
# Out:
#                       School Type  Student Population Total School Budget  \
# school_name
# Bailey High School       District                4976       $3,124,928.00
# Cabrera High School       Charter                1858       $1,081,356.00
# Figueroa High School     District                2949       $1,884,411.00
# Ford High School         District                2739       $1,763,916.00
# Griffin High School       Charter                1468         $917,500.00
# Hernandez High School    District                4635       $3,022,020.00
# Holden High School        Charter                 427         $248,087.00
# Huang High School        District                2917       $1,910,635.00
# Johnson High School      District                4761       $3,094,650.00
# Pena High School          Charter                 962         $585,858.00
# Rodriguez High School    District                3999       $2,547,363.00
# ...

# %%
spending_math_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Average Math Score"].mean()
spending_reading_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Average Reading Score"].mean()
spending_passing_math = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Math Passing Rate"].mean()
spending_passing_reading = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Reading Passing Rate"].mean()
overall_passing_spending = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Overall Passing Rate"].mean()
# Out:
# /var/folders/t1/m31xbjfs0qs62l508cf4hcv40000gn/T/ipykernel_8223/936073222.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   spending_math_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Average Math Score"].mean()
# /var/folders/t1/m31xbjfs0qs62l508cf4hcv40000gn/T/ipykernel_8223/936073222.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   spending_reading_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"])["Average Reading Score"].mean()
# ...

# %%
# Assemble into DataFrame
spending_summary = pd.DataFrame({
    "Average Math Score": spending_math_scores,
    "Average Reading Score": spending_reading_scores,
    "% Passing Math": spending_passing_math,
    "% Passing Reading": spending_passing_reading,
    "% Overall Passing": overall_passing_spending
})

# Display results
spending_summary
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                   83.455399              83.933814
# $585-630                                81.899826              83.155286
# $630-645                                78.518855              81.624473
# $645-680                                76.997210              81.027843
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                               93.460096          96.610877
# $585-630                            87.133538          92.718205
# $630-645                            73.484209          84.391793
# $645-680                            66.164813          81.133951
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$585                                  90.369459
# $585-630                               81.418596
# ...

# %%
#-------------------------------------------------------------------------------------------------------------------

# %%
# Establish the bins.
size_bins = [0, 1000, 2000, 5000]
labels = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
per_school_summary["School Size"] = pd.cut(school_spending_df["Student Population"], bins=size_bins, labels=labels)
per_school_summary
# Out:
#                       School Type  Student Population Total School Budget  \
# school_name
# Bailey High School       District                4976       $3,124,928.00
# Cabrera High School       Charter                1858       $1,081,356.00
# Figueroa High School     District                2949       $1,884,411.00
# Ford High School         District                2739       $1,763,916.00
# Griffin High School       Charter                1468         $917,500.00
# Hernandez High School    District                4635       $3,022,020.00
# Holden High School        Charter                 427         $248,087.00
# Huang High School        District                2917       $1,910,635.00
# Johnson High School      District                4761       $3,094,650.00
# Pena High School          Charter                 962         $585,858.00
# Rodriguez High School    District                3999       $2,547,363.00
# ...

# %%
# Calculate averages for the desired columns.
size_math_scores = per_school_summary.groupby(["School Size"])["Average Math Score"].mean()
size_reading_scores = per_school_summary.groupby(["School Size"])["Average Reading Score"].mean()
size_passing_math = per_school_summary.groupby(["School Size"])["Math Passing Rate"].mean()
size_passing_reading = per_school_summary.groupby(["School Size"])["Reading Passing Rate"].mean()
size_overall_passing = per_school_summary.groupby(["School Size"])["Overall Passing Rate"].mean()
# Out:
# /var/folders/t1/m31xbjfs0qs62l508cf4hcv40000gn/T/ipykernel_8223/3376234912.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   size_math_scores = per_school_summary.groupby(["School Size"])["Average Math Score"].mean()
# /var/folders/t1/m31xbjfs0qs62l508cf4hcv40000gn/T/ipykernel_8223/3376234912.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   size_reading_scores = per_school_summary.groupby(["School Size"])["Average Reading Score"].mean()
# ...

# %%
# Use the scores to create a new DataFrame called size_summary
size_summary = pd.DataFrame({
    "Average Math Score": per_school_summary.groupby("School Size")["Average Math Score"].mean(),
    "Average Reading Score": per_school_summary.groupby("School Size")["Average Reading Score"].mean(),
    "Math Passing Rate": per_school_summary.groupby("School Size")["Math Passing Rate"].mean(),
    "Reading Passing Rate": per_school_summary.groupby("School Size")["Reading Passing Rate"].mean(),
    "Overall Passing Rate": per_school_summary.groupby("School Size")["Overall Passing Rate"].mean()
})

# Display results
size_summary
# Out:
# /var/folders/t1/m31xbjfs0qs62l508cf4hcv40000gn/T/ipykernel_8223/2968437072.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   "Average Math Score": per_school_summary.groupby("School Size")["Average Math Score"].mean(),
# /var/folders/t1/m31xbjfs0qs62l508cf4hcv40000gn/T/ipykernel_8223/2968437072.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   "Average Reading Score": per_school_summary.groupby("School Size")["Average Reading Score"].mean(),
# ...

# %%
#-------------------------------------------------------------------------------------------------------------------

# %%
# Calculate mean scores and passing rates by school type
average_math_score_by_type = per_school_summary.groupby(["School Type"])["Average Math Score"].mean()
average_reading_score_by_type = per_school_summary.groupby(["School Type"])["Average Reading Score"].mean()
average_math_passing_rate_by_type = per_school_summary.groupby(["School Type"])["Math Passing Rate"].mean()
average_reading_passing_rate_by_type = per_school_summary.groupby(["School Type"])["Reading Passing Rate"].mean()
average_overall_passing_rate_by_type = per_school_summary.groupby(["School Type"])["Overall Passing Rate"].mean()

# %%
# Create the type_summary DataFrame
type_summary = pd.DataFrame({
    "Average Math Score": average_math_score_by_type,
    "Average Reading Score": average_reading_score_by_type,
    "Math Passing Rate": average_math_passing_rate_by_type,
    "Reading Passing Rate": average_reading_passing_rate_by_type,
    "Overall Passing Rate": average_overall_passing_rate_by_type
})

# Display the type_summary DataFrame
type_summary
# Out:
#              Average Math Score  Average Reading Score  Math Passing Rate  \
# School Type
# Charter               83.473852              83.896421          93.620830
# District              76.956733              80.966636          66.548453
#
#              Reading Passing Rate  Overall Passing Rate
# School Type
# Charter                 96.586489             90.432244
# District                80.799062             53.672208
